# %%
import pandas as pd
from bs4 import BeautifulSoup
import concurrent.futures
import requests
import copy

pd.options.display.max_columns = None

# %%
ufc_dict_empty= {
    "Date":[],
    "Winner":[],
    "Method":[],
    "Referee":[],
    "N_rounds":[],
    "W_round":[],
    "W_round_time":[],
    "R_fighter":[],
    "B_fighter":[],
    "R_KD":[],
    "B_KD":[],
    "R_total_str":[],
    "B_total_str":[],
    "R_TD":[],
    "B_TD":[],
    "R_sub_att":[],
    "B_sub_att":[],
    "R_rev":[],
    "B_rev":[],
    "R_ctrl":[],
    "B_ctrl":[],
    "R_sig_str":[],
    "B_sig_str":[],
    "R_sig_str_head":[],
    "B_sig_str_head":[],
    "R_sig_str_body":[],
    "B_sig_str_body":[],
    "R_sig_str_leg":[],
    "B_sig_str_leg":[],
    "R_sig_str_dist":[],
    "B_sig_str_dist":[],
    "R_sig_str_clinch":[],
    "B_sig_str_clinch":[],
    "R_sig_str_ground":[],
    "B_sig_str_ground":[],
}

# %%
# ufc_dict = copy.deepcopy(ufc_dict_empty)
# user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36 Edg/113.0.1774.35"
# main_url = 'http://ufcstats.com/statistics/events/completed?page=all'
# response = requests.get(main_url, headers={"User-Agent": user_agent})
# main_soup = BeautifulSoup(response.content, "lxml")
# events = main_soup.find_all('tr', class_="b-statistics__table-row")[2:]

# for event in events:
#     date = event.find('span', class_="b-statistics__date").text.strip()
#     event_url = event.find('a', class_="b-link b-link_style_black")['href']
#     event_response = requests.get(event_url, headers={"User-Agent": user_agent})
#     event_soup = BeautifulSoup(event_response.content, "lxml")
#     fights = event_soup.find_all('tr', class_="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click")
#     for fight in fights:
        
#         fight_url = fight['data-link']
         
#         fight_response = requests.get(fight_url, headers={"User-Agent": user_agent})
#         fight_soup = BeautifulSoup(fight_response.content, "lxml")

#         valid_check = fight_soup.find('section', class_="b-fight-details__section js-fight-section")
#         if valid_check.text.strip() == "Round-by-round stats not currently available.":
#             continue

#         win_lose = fight_soup.find_all('div', class_="b-fight-details__person")
#         for fighter in win_lose:
#             txt = fighter.text.strip().replace('\n', '').split('  ')
#             if txt[0] == 'W':
#                 winner = txt[1]
#             elif txt[0] == 'D':
#                 winner = 'Draw'
#         ufc_dict['Winner'].append(winner)

#         method = fight_soup.find('i', class_="b-fight-details__text-item_first").find('i', attrs={'style':"font-style: normal"}).text.strip()
#         ufc_dict['Method'].append(method)
        
#         info_items = fight_soup.find_all('i', class_="b-fight-details__text-item")
#         info = [items.text.strip().split('\n', maxsplit=1) for items in info_items]
#         try:    
#             referee = info[3][1].strip()
#         except:
#             referee = None
#         ufc_dict['Referee'].append(referee)

#         w_round = info[0][1].strip()
#         w_round_time = info[1][1].strip()
#         n_rounds = info[2][1].strip()[0]
#         ufc_dict['W_round'].append(w_round)
#         ufc_dict['W_round_time'].append(w_round_time)
#         ufc_dict['N_rounds'].append(n_rounds)
        
#         r_fighter = fight_soup.find('i', class_="b-fight-details__charts-name b-fight-details__charts-name_pos_left js-chart-name", attrs={'data-color':'red'}).text.strip()
#         b_fighter = fight_soup.find('i', class_="b-fight-details__charts-name b-fight-details__charts-name_pos_right js-chart-name", attrs={'data-color':'blue'}).text.strip()
#         ufc_dict['R_fighter'].append(r_fighter)
#         ufc_dict['B_fighter'].append(b_fighter)


#         tbl_items = fight_soup.find_all('tbody', class_="b-fight-details__table-body")
#         total_str_stats = tbl_items[0]
#         sig_str_stats = tbl_items[2]

#         total_str_items = total_str_stats.find('tr', class_="b-fight-details__table-row").text.split('\n')
#         total_str_items = [item.strip() for item in total_str_items if item.strip()]
        
#         r_kd = total_str_items[2]
#         b_kd = total_str_items[3]
#         ufc_dict['R_KD'].append(r_kd)
#         ufc_dict['B_KD'].append(b_kd)

#         r_total_str = total_str_items[8]
#         b_total_str = total_str_items[9]
#         ufc_dict['R_total_str'].append(r_total_str)
#         ufc_dict['B_total_str'].append(b_total_str)

#         r_td = total_str_items[10]
#         b_td = total_str_items[11]
#         ufc_dict['R_TD'].append(r_td)
#         ufc_dict['B_TD'].append(b_td)

#         r_sub_att = total_str_items[14]
#         b_sub_att = total_str_items[15]
#         ufc_dict['R_sub_att'].append(r_sub_att)
#         ufc_dict['B_sub_att'].append(b_sub_att)

#         r_rev = total_str_items[16]
#         b_rev = total_str_items[17]
#         ufc_dict['R_rev'].append(r_rev)
#         ufc_dict['B_rev'].append(b_rev)

#         r_ctrl = total_str_items[18]
#         b_ctrl = total_str_items[19]
#         ufc_dict['R_ctrl'].append(r_ctrl)
#         ufc_dict['B_ctrl'].append(b_ctrl)

#         sig_str_items = sig_str_stats.find('tr', class_="b-fight-details__table-row").text.split('\n')
#         sig_str_items = [item.strip() for item in sig_str_items if item.strip()]

#         r_sig_str = sig_str_items[2]
#         b_sig_str = sig_str_items[3]
#         ufc_dict['R_sig_str'].append(r_sig_str)
#         ufc_dict['B_sig_str'].append(b_sig_str)
        
#         r_sig_str_head = sig_str_items[6]
#         b_sig_str_head = sig_str_items[7]
#         ufc_dict['R_sig_str_head'].append(r_sig_str_head)
#         ufc_dict['B_sig_str_head'].append(b_sig_str_head)

#         r_sig_str_body = sig_str_items[8]
#         b_sig_str_body = sig_str_items[9]
#         ufc_dict['R_sig_str_body'].append(r_sig_str_body)
#         ufc_dict['B_sig_str_body'].append(b_sig_str_body)

#         r_sig_str_leg = sig_str_items[10]
#         b_sig_str_leg = sig_str_items[11]
#         ufc_dict['R_sig_str_leg'].append(r_sig_str_leg)
#         ufc_dict['B_sig_str_leg'].append(b_sig_str_leg)

#         r_sig_str_dist = sig_str_items[12]
#         b_sig_str_dist = sig_str_items[13]
#         ufc_dict['R_sig_str_dist'].append(r_sig_str_dist)
#         ufc_dict['B_sig_str_dist'].append(b_sig_str_dist)

#         r_sig_str_clinch = sig_str_items[14]
#         b_sig_str_clinch = sig_str_items[15]
#         ufc_dict['R_sig_str_clinch'].append(r_sig_str_clinch)
#         ufc_dict['B_sig_str_clinch'].append(b_sig_str_clinch)

#         r_sig_str_ground = sig_str_items[16]
#         b_sig_str_ground = sig_str_items[17]
#         ufc_dict['R_sig_str_ground'].append(r_sig_str_ground)
#         ufc_dict['B_sig_str_ground'].append(b_sig_str_ground)

#         ufc_dict["Date"].append(date)
#     #     break
#     # break

# %%
def get_fight_details(fight, date):
    fight_dict = {}

    fight_url = fight['data-link']
        
    fight_response = requests.get(fight_url, headers={"User-Agent": user_agent})
    fight_soup = BeautifulSoup(fight_response.content, "lxml")

    valid_check = fight_soup.find('section', class_="b-fight-details__section js-fight-section")
    if valid_check.text.strip() == "Round-by-round stats not currently available.":
        return fight_dict

    winner = None
    win_lose = fight_soup.find_all('div', class_="b-fight-details__person")
    for fighter in win_lose:
        txt = fighter.text.strip().replace('\n', '').split('  ')
        if txt[0] == 'W':
            winner = txt[1]
        elif txt[0] == 'D':
            winner = 'Draw'
    fight_dict['Winner'] = winner

    method = fight_soup.find('i', class_="b-fight-details__text-item_first").find('i', attrs={'style':"font-style: normal"}).text.strip()
    fight_dict['Method'] = method

    info_items = fight_soup.find_all('i', class_="b-fight-details__text-item")
    info = [items.text.strip().split('\n', maxsplit=1) for items in info_items]
    try:    
        referee = info[3][1].strip()
    except:
        referee = None
    fight_dict['Referee'] = referee

    w_round = info[0][1].strip()
    w_round_time = info[1][1].strip()
    n_rounds = info[2][1].strip()[0]
    fight_dict['W_round'] = w_round
    fight_dict['W_round_time'] = w_round_time
    fight_dict['N_rounds'] = n_rounds

    r_fighter = fight_soup.find('i', class_="b-fight-details__charts-name b-fight-details__charts-name_pos_left js-chart-name", attrs={'data-color':'red'}).text.strip()
    b_fighter = fight_soup.find('i', class_="b-fight-details__charts-name b-fight-details__charts-name_pos_right js-chart-name", attrs={'data-color':'blue'}).text.strip()
    fight_dict['R_fighter'] = r_fighter
    fight_dict['B_fighter'] = b_fighter


    tbl_items = fight_soup.find_all('tbody', class_="b-fight-details__table-body")
    total_str_stats = tbl_items[0]
    sig_str_stats = tbl_items[2]

    total_str_items = total_str_stats.find('tr', class_="b-fight-details__table-row").text.split('\n')
    total_str_items = [item.strip() for item in total_str_items if item.strip()]

    r_kd = total_str_items[2]
    b_kd = total_str_items[3]
    fight_dict['R_KD'] = r_kd
    fight_dict['B_KD'] = b_kd

    r_total_str = total_str_items[8]
    b_total_str = total_str_items[9]
    fight_dict['R_total_str'] = r_total_str
    fight_dict['B_total_str'] = b_total_str

    r_td = total_str_items[10]
    b_td = total_str_items[11]
    fight_dict['R_TD'] = r_td
    fight_dict['B_TD'] = b_td

    r_sub_att = total_str_items[14]
    b_sub_att = total_str_items[15]
    fight_dict['R_sub_att'] = r_sub_att
    fight_dict['B_sub_att'] = b_sub_att

    r_rev = total_str_items[16]
    b_rev = total_str_items[17]
    fight_dict['R_rev'] = r_rev
    fight_dict['B_rev'] = b_rev

    r_ctrl = total_str_items[18]
    b_ctrl = total_str_items[19]
    fight_dict['R_ctrl'] = r_ctrl
    fight_dict['B_ctrl'] = b_ctrl

    sig_str_items = sig_str_stats.find('tr', class_="b-fight-details__table-row").text.split('\n')
    sig_str_items = [item.strip() for item in sig_str_items if item.strip()]

    r_sig_str = sig_str_items[2]
    b_sig_str = sig_str_items[3]
    fight_dict['R_sig_str'] = r_sig_str
    fight_dict['B_sig_str'] = b_sig_str

    r_sig_str_head = sig_str_items[6]
    b_sig_str_head = sig_str_items[7]
    fight_dict['R_sig_str_head'] = r_sig_str_head
    fight_dict['B_sig_str_head'] = b_sig_str_head

    r_sig_str_body = sig_str_items[8]
    b_sig_str_body = sig_str_items[9]
    fight_dict['R_sig_str_body'] = r_sig_str_body
    fight_dict['B_sig_str_body'] = b_sig_str_body

    r_sig_str_leg = sig_str_items[10]
    b_sig_str_leg = sig_str_items[11]
    fight_dict['R_sig_str_leg'] = r_sig_str_leg
    fight_dict['B_sig_str_leg'] = b_sig_str_leg

    r_sig_str_dist = sig_str_items[12]
    b_sig_str_dist = sig_str_items[13]
    fight_dict['R_sig_str_dist'] = r_sig_str_dist
    fight_dict['B_sig_str_dist'] = b_sig_str_dist

    r_sig_str_clinch = sig_str_items[14]
    b_sig_str_clinch = sig_str_items[15]
    fight_dict['R_sig_str_clinch'] = r_sig_str_clinch
    fight_dict['B_sig_str_clinch'] = b_sig_str_clinch

    r_sig_str_ground = sig_str_items[16]
    b_sig_str_ground = sig_str_items[17]
    fight_dict['R_sig_str_ground'] = r_sig_str_ground
    fight_dict['B_sig_str_ground'] = b_sig_str_ground
    
    fight_dict["Date"] = date

    return fight_dict

# %%
ufc_dict = copy.deepcopy(ufc_dict_empty)
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36 Edg/113.0.1774.35"
main_url = 'http://ufcstats.com/statistics/events/completed?page=all'
session = requests.Session()
session.headers.update({"User-Agent": user_agent})
main_response = session.get(main_url)
main_soup = BeautifulSoup(main_response.content, "lxml")
events = main_soup.find_all('tr', class_="b-statistics__table-row")[2:]

for event in events:
    date = event.find('span', class_="b-statistics__date").text.strip()
    event_url = event.find('a', class_="b-link b-link_style_black")['href']
    event_response = session.get(event_url)
    event_soup = BeautifulSoup(event_response.content, "lxml")
    fights = event_soup.find_all('tr', class_="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click")

    with concurrent.futures.ThreadPoolExecutor() as executor:
        fight_details = list(executor.map(lambda fight: get_fight_details(fight, date), fights))

    for fight_detail in fight_details:
        for key, value in fight_detail.items():
            ufc_dict[key].append(value)

# %%
for k in ufc_dict.keys():
    print(f'{k}, {len(ufc_dict[k])}')
# Out:
# Date, 7122
# Winner, 7122
# Method, 7122
# Referee, 7122
# N_rounds, 7122
# W_round, 7122
# W_round_time, 7122
# R_fighter, 7122
# B_fighter, 7122
# R_KD, 7122
# B_KD, 7122
# R_total_str, 7122
# B_total_str, 7122
# R_TD, 7122
# B_TD, 7122
# R_sub_att, 7122
# B_sub_att, 7122
# R_rev, 7122
# B_rev, 7122
# R_ctrl, 7122
# B_ctrl, 7122
# R_sig_str, 7122
# B_sig_str, 7122
# R_sig_str_head, 7122
# B_sig_str_head, 7122
# R_sig_str_body, 7122
# B_sig_str_body, 7122
# R_sig_str_leg, 7122
# B_sig_str_leg, 7122
# R_sig_str_dist, 7122
# B_sig_str_dist, 7122
# R_sig_str_clinch, 7122
# B_sig_str_clinch, 7122
# R_sig_str_ground, 7122
# B_sig_str_ground, 7122

# %%
ufc_df = pd.DataFrame(ufc_dict)
ufc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7122 entries, 0 to 7121
# Data columns (total 35 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              7122 non-null   object
#  1   Winner            7050 non-null   object
#  2   Method            7122 non-null   object
#  3   Referee           7090 non-null   object
#  4   N_rounds          7122 non-null   object
#  5   W_round           7122 non-null   object
#  6   W_round_time      7122 non-null   object
#  7   R_fighter         7122 non-null   object
#  8   B_fighter         7122 non-null   object
#  9   R_KD              7122 non-null   object
#  10  B_KD              7122 non-null   object
#  11  R_total_str       7122 non-null   object
#  12  B_total_str       7122 non-null   object
#  13  R_TD              7122 non-null   object
#  14  B_TD              7122 non-null   object
#  15  R_sub_att         7122 non-null   object
#  16  B_sub_att         7122 non-null   object
#  17  R_rev             7122 non-null   object
#  18  B_rev             7122 non-null   object
#  19  R_ctrl            7122 non-null   object
#  20  B_ctrl            7122 non-null   object
#  21  R_sig_str         7122 non-null   object
#  22  B_sig_str         7122 non-null   object
#  23  R_sig_str_head    7122 non-null   object
#  24  B_sig_str_head    7122 non-null   object
#  25  R_sig_str_body    7122 non-null   object
#  26  B_sig_str_body    7122 non-null   object
#  27  R_sig_str_leg     7122 non-null   object
#  28  B_sig_str_leg     7122 non-null   object
#  29  R_sig_str_dist    7122 non-null   object
#  30  B_sig_str_dist    7122 non-null   object
#  31  R_sig_str_clinch  7122 non-null   object
#  32  B_sig_str_clinch  7122 non-null   object
#  33  R_sig_str_ground  7122 non-null   object
#  34  B_sig_str_ground  7122 non-null   object
# dtypes: object(35)
# memory usage: 1.9+ MB

# %%
ufc_df[['W_round_time', 'R_ctrl', 'B_ctrl']]
# Out:
#         W_round_time R_ctrl B_ctrl
# 0    0 days 00:05:00  13:12   7:11
# 1    0 days 00:01:01   0:41   7:11
# 2    0 days 00:05:00   0:11   0:13
# 3    0 days 00:04:15   0:07   0:23
# 4    0 days 00:01:50   0:01   0:00
# ...              ...    ...    ...
# 7117 0 days 00:02:50     --     --
# 7118 0 days 00:04:52     --     --
# 7119 0 days 00:12:13     --     --
# 7120 0 days 00:00:58     --     --
# 7121 0 days 00:00:20     --     --
#
# [7122 rows x 3 columns]

# %%
ufc_df['Date'] = pd.to_datetime(ufc_df['Date'])

for col in ['N_rounds','W_round', 'R_KD', 'B_KD', 'R_sub_att', 'B_sub_att', 'R_rev', 'B_rev']:
    ufc_df[col] = ufc_df[col].replace('N', '1')
    ufc_df[col] = pd.to_numeric(ufc_df[col])

for col in ['W_round_time', 'R_ctrl', 'B_ctrl']:
    ufc_df[col] = ufc_df[col].replace('--', '0:00')
    ufc_df[col] = pd.to_timedelta('00:' + ufc_df[col])

for col in ufc_df.select_dtypes(include='object').columns[5:]:
    splitted = ufc_df[col].apply(lambda x: x.split(' of '))
    ufc_df[col + '_att'] = splitted.apply(lambda x: int(x[1]))
    ufc_df[col + '_land'] = splitted.apply(lambda x: int(x[0]))
    ufc_df.drop(columns=col, inplace=True)

# %%
ufc_df.to_csv('data/fight_data.csv')
