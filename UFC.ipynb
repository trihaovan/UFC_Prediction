# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)

# %%
ufc_df = pd.read_csv('data/data.csv')
ufc_df.head()
# Out:
#        R_fighter          B_fighter        Referee        date  \
# 0   Adrian Yanez      Gustavo Lopez  Chris Tognoni  2021-03-20
# 1   Trevin Giles      Roman Dolidze      Herb Dean  2021-03-20
# 2    Tai Tuivasa    Harry Hunsucker      Herb Dean  2021-03-20
# 3  Cheyanne Buys  Montserrat Conejo     Mark Smith  2021-03-20
# 4  Marion Reneau      Macy Chiasson     Mark Smith  2021-03-20
#
#                  location Winner  title_bout       weight_class  B_avg_KD  \
# 0  Las Vegas, Nevada, USA    Red       False       Bantamweight     0.000
# 1  Las Vegas, Nevada, USA    Red       False       Middleweight     0.500
# 2  Las Vegas, Nevada, USA    Red       False        Heavyweight       NaN
# 3  Las Vegas, Nevada, USA   Blue       False   WomenStrawweight       NaN
# 4  Las Vegas, Nevada, USA   Blue       False  WomenBantamweight     0.125
#
#    B_avg_opp_KD  ...  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# 0           0.0  ...                            0                1
# ...

# %%
ufc_df[ufc_df.isnull().any(axis=1)]
# Out:
#                       R_fighter                 B_fighter  \
# 2                   Tai Tuivasa           Harry Hunsucker
# 3                 Cheyanne Buys         Montserrat Conejo
# 8                Montel Jackson             Jesse Strader
# 9                   Bruno Silva                   JP Buys
# 10                   Manel Kape           Matheus Nicolau
# 13             Charles Jourdain              Marcelo Rojo
# 18             Nasrat Haqparast               Rafa Garcia
# 22              Gloria de Paula              Jinh Yu Frey
# 34                   Uros Medic                Aalon Cruz
# 35            Kennedy Nzechukwu             Carlos Ulberg
# 40                Vince Cachero           Ronnie Lawrence
# 55               Aiemann Zahabi           Drako Rodriguez
# 56               Serghei Spivac            Jared Vanderaa
# 58                 Shana Dobson             Casey O'Neill
# 67                   Gabe Green               Philip Rowe
# ...

# %%
ufc_df.isna().sum()
# Out:
# R_fighter                          0
# B_fighter                          0
# Referee                           32
# date                               0
# location                           0
# Winner                             0
# title_bout                         0
# weight_class                       0
# B_avg_KD                        1427
# B_avg_opp_KD                    1427
# B_avg_SIG_STR_pct               1427
# B_avg_opp_SIG_STR_pct           1427
# B_avg_TD_pct                    1427
# B_avg_opp_TD_pct                1427
# B_avg_SUB_ATT                   1427
# B_avg_opp_SUB_ATT               1427
# B_avg_REV                       1427
# B_avg_opp_REV                   1427
# B_avg_SIG_STR_att               1427
# B_avg_SIG_STR_landed            1427
# B_avg_opp_SIG_STR_att           1427
# B_avg_opp_SIG_STR_landed        1427
# B_avg_TOTAL_STR_att             1427
# B_avg_TOTAL_STR_landed          1427
# B_avg_opp_TOTAL_STR_att         1427
# ...

# %%
debuts = ufc_df.loc[:, ufc_df.isna().sum() > 700]
ufc_df.loc[:, ufc_df.isna().sum() > 700] = debuts.fillna(debuts.median())

# %%
ufc_df.isna().sum()[ufc_df.isna().sum() > 0]
# Out:
# Referee          32
# B_Stance         66
# B_Height_cms     10
# B_Weight_lbs      8
# R_Stance         29
# R_Height_cms      4
# R_Reach_cms     406
# R_Weight_lbs      2
# B_age           172
# R_age            63
# dtype: int64

# %%
missing_height = ufc_df[['B_fighter', 'B_Height_cms']][ufc_df[['B_Height_cms']].isnull().any(axis = 1)]
missing_height
# Out:
#                B_fighter  B_Height_cms
# 4270    Edward Faaloloto           NaN
# 4388    Edward Faaloloto           NaN
# 5847       Frank Caracci           NaN
# 5859      Adriano Santos           NaN
# 5867       Noe Hernandez           NaN
# 5894          Sam Fulton           NaN
# 5903      Saeed Hosseini           NaN
# 5981          John Dowdy           NaN
# 5992  Felix Lee Mitchell           NaN
# 6010          Ray Wizard           NaN

# %%
ufc_df.dropna(subset=['B_Height_cms', 'R_Height_cms'], inplace=True)

# %%
ufc_df.isna().sum()[ufc_df.isna().sum() > 0]
# Out:
# Referee         32
# B_Stance        57
# R_Stance        26
# R_Reach_cms    398
# B_age          163
# R_age           58
# dtype: int64

# %%
ref_top20 = ufc_df.Referee.value_counts().head(20)
ref_top20
# Out:
# Herb Dean           858
# John McCarthy       640
# Dan Miragliotta     400
# Mario Yamasaki      392
# Marc Goddard        346
# Yves Lavigne        264
# Steve Mazzagatti    201
# Leon Roberts        192
# Keith Peterson      189
# Jason Herzog        178
# Chris Tognoni       162
# Mark Smith          146
# Josh Rosenthal      122
# Kevin MacDonald      82
# Steve Perceval       78
# Jerin Valel          75
# John Sharp           75
# Kevin Mulhall        62
# Kerry Hatley         51
# Osiris Maia          47
# Name: Referee, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = ref_top20.index.astype(str), y = ref_top20.values,)
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
nan_ref_id = ufc_df[ufc_df['Referee'].isna()]
nan_ref_id
# Out:
#                  R_fighter              B_fighter Referee        date  \
# 10              Manel Kape        Matheus Nicolau     NaN  2021-03-13
# 138        Gabriel Benitez          Justin Jaynes     NaN  2020-12-05
# 237   Germaine de Randamie          Julianna Pena     NaN  2020-10-03
# 304         Mariya Agapova           Shana Dobson     NaN  2020-08-22
# 346        Fabricio Werdum   Alexander Gustafsson     NaN  2020-07-25
# 404         Curtis Blaydes       Alexander Volkov     NaN  2020-06-20
# 456            Ricky Simon               Ray Borg     NaN  2020-05-13
# 525          Lando Vannata         Yancy Medeiros     NaN  2020-02-15
# 742         Omari Akhmedov           Zak Cummings     NaN  2019-09-07
# 889            Bea Malecki           Duda Santana     NaN  2019-06-01
# 987           Alexis Davis          Jennifer Maia     NaN  2019-03-23
# 1290   Alexander Hernandez  Olivier Aubin-Mercier     NaN  2018-07-28
# ...

# %%
nan_refs = ['Mark Smith', 'Mark Smith', ]
